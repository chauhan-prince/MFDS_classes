# %% [markdown]
# <a href="https://colab.research.google.com/github/chauhan-prince/MFDS_classes/blob/main/RandomNumber.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

#Generate 5 peseudo-rendom numbers between 1 and 100
random_numbers = [random.randint(1,100) for _ in range(5)]
print("Random Numbers:", random_numbers)
# Out:
# Random Numbers: [64, 65, 75, 5, 41]

# %%
# Set the seed
random.seed(5)

#Generate the same sequence every time
repeatable_numbers = [random.randint(1,100) for _ in range(5)]
print("Repeatable Numbers:", repeatable_numbers)
# Out:
# Repeatable Numbers: [80, 33, 95, 46, 89]

# %%
#if the seed is the same, the random numbers will be the same, make results reproducible.

# %%
generate random number
generate random number
